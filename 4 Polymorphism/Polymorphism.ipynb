# %% [markdown]
# # Triangle Assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sum of two sides > third side

# %%
class Triangle:

    def __init__(self, a, b, c):
        self.a = a 
        self.b = b 
        self.c = c

    def isTriangle(self):
        a = self.a
        b = self.b
        c = self.c
        if (a+b>c) and (b+c>a) and (c+a>b):
            t = True
        else:
            t = False
        return t 
    
    def perimeter(self):
        if self.isTriangle():
            p = self.a + self.b + self.c 
        else:
            print(f'The given sides {self.a}, {self.b} and {self.c} DO NOT FORM a triangle')
            p = None
        return p 
    
    def area(self):
        if self.isTriangle():
            s = (self.a + self.b + self.c)/2
            a = (s*(s-self.a)*(s-self.b)*(s-self.c))**(1/2)
        else:
            print(f'The given sides {self.a}, {self.b} and {self.c} DO NOT FORM a triangle')
            a = None
        return a

# %%
t1 = Triangle(3, 4, 5)
print(type(t1))
# Out:
# <class '__main__.Triangle'>

# %%
t1.a
# Out:
# 3

# %%
t1.b
# Out:
# 4

# %%
t1.c
# Out:
# 5

# %%
t1.isTriangle()
# Out:
# True

# %%
p1 = t1.perimeter()

# %%
p1
# Out:
# 12

# %%
a1 = t1.area()

# %%
a1
# Out:
# 6.0

# %%
t2 = Triangle(1, 2, 4)
print(type(t2))
# Out:
# <class '__main__.Triangle'>

# %%
t2.isTriangle()
# Out:
# False

# %%
t2.perimeter()
# Out:
# The given sides 1, 2 and 4 DO NOT FORM a triangle

# %%
t2.area()
# Out:
# The given sides 1, 2 and 4 DO NOT FORM a triangle

# %%
t3 = Triangle(12, 13, 14)

# %%
for i in [t1, t2, t3]:
    print(f'Sides of triangle : {i.a}, {i.b}, {i.c}')
    print(f'Perimeter of triangle : {i.perimeter()}')
    print(f'Area of the triangle : {i.area()}')
    print('\n=========================================\n')
# Out:
# Sides of triangle : 3, 4, 5
# Perimeter of triangle : 12
# Area of the triangle : 6.0
#
# ...
#
# Sides of triangle : 1, 2, 4
# The given sides 1, 2 and 4 DO NOT FORM a triangle
# Perimeter of triangle : None
# The given sides 1, 2 and 4 DO NOT FORM a triangle
# Area of the triangle : None
#
# ...
#
# Sides of triangle : 12, 13, 14
# Perimeter of triangle : 39
# Area of the triangle : 72.30793524918272
#
# ...

# %% [markdown]
# # Polymorphism

# %% [markdown]
# ### 1. Polymorphism in functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "ETLHive"
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 7

# %%
b = [1, 2, 3, "Example", True, False, 14.5, 12, 13, 15]
type(b)
# Out:
# list

# %%
len(b)
# Out:
# 10

# %%
c = (1, 2, 3)
type(c)
# Out:
# tuple

# %%
len(c)
# Out:
# 3

# %%
d = {
    "name" : "Utkarsh",
    "age" : 28,
    "Occupation" : "Data Scientist",
    "Salary" : 15000
}
type(d)
# Out:
# dict

# %%
len(d)
# Out:
# 4

# %% [markdown]
# ### 2. Polymorphism in operators
# ![image.png](attachment:image.png)

# %%
3 + 7
# Out:
# 10

# %%
13.4 + 12.1
# Out:
# 25.5

# %%
"example1"+"example2"
# Out:
# 'example1example2'

# %%
[1, 2, 3, 4] + [5, 6, 7]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### Polymorphism in classes

# %%
dir(Triangle)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'area',
#  'isTriangle',
#  'perimeter']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
h1 = [11, 12, 13, 14, 15]
type(h1)
# Out:
# list

# %%
h1.index(13)
# Out:
# 2

# %%
h1.count(14)
# Out:
# 1

# %%
h2 = (21, 22, 23, 24, 25, 26)
type(h2)
# Out:
# tuple

# %%
h2.index(25)
# Out:
# 4

# %%
h2.count(100)
# Out:
# 0

# %% [markdown]
# ### Implementing polymorphism in classes

# %%
class India:

    def capital(self):
        print("New Delhi is capital of India")

    def language(self):
        print("Hindi is widely spoken in India")

# %%
class USA:

    def capital(self):
        print("Washington D.C. is capital of USA")

    def language(self):
        print("English is widely spoken in USA")

# %%
class France:

    def capital(self):
        print("Paris is capital of France")

    def language(self):
        print("French is widely spoken in France")

# %%
c1 = India()
c2 = USA()
c3 = France()

# %%
c1.language()
# Out:
# Hindi is widely spoken in India

# %%
c2.language()
# Out:
# English is widely spoken in USA

# %%
c3.language()
# Out:
# French is widely spoken in France

# %%
for i in [c1, c2, c3]:
    print(type(i))
    i.capital()
    i.language()
    print('\n=====================================\n')
# Out:
# <class '__main__.India'>
# New Delhi is capital of India
# Hindi is widely spoken in India
#
# ...
#
# <class '__main__.USA'>
# Washington D.C. is capital of USA
# English is widely spoken in USA
#
# ...
#
# <class '__main__.France'>
# Paris is capital of France
# French is widely spoken in France
#
# ...

# %% [markdown]
# ### Polymorphism to calculate area, perimeter

# %%
class Rectangle:

    def __init__(self, width, height):
        self.width = width 
        self.height = height

    def perimeter(self):
        return 2*(self.width + self.height)
    
    def area(self):
        return self.width*self.height

# %%
from math import pi 
pi
# Out:
# 3.141592653589793

# %%
class Circle:

    def __init__(self, radius):
        self.radius = radius

    def perimeter(self):
        return 2*pi*self.radius
    
    def area(self):
        return pi*(self.radius**2)

# %%
s1 = Triangle(13, 14, 15)
s2 = Circle(14)
s3 = Rectangle(10, 15)
s4 = Triangle(1, 2, 3)
s5 = Circle(10)
s6 = Rectangle(20, 12)

# %%
shapes = [s1, s2, s3, s4, s5, s6]

# %%
shapes

# %%
for i in shapes:
    print(type(i))
    print(f'Perimeter : {i.perimeter()}')
    print(f'Area : {i.area()}')
    print('\n=======================================\n')
# Out:
# <class '__main__.Triangle'>
# Perimeter : 42
# Area : 84.0
#
# ...
#
# <class '__main__.Circle'>
# Perimeter : 87.96459430051421
# Area : 615.7521601035994
#
# ...
#
# <class '__main__.Rectangle'>
# Perimeter : 50
# Area : 150
#
# ...
#
# <class '__main__.Triangle'>
# The given sides 1, 2 and 3 DO NOT FORM a triangle
# Perimeter : None
# The given sides 1, 2 and 3 DO NOT FORM a triangle
# Area : None
#
# ...
#
# <class '__main__.Circle'>
# Perimeter : 62.83185307179586
# Area : 314.1592653589793
#
# ...
#
# <class '__main__.Rectangle'>
# Perimeter : 64
# Area : 240
#
# ...

# %%
type(s1)
# Out:
# __main__.Triangle

# %%
type(s2)
# Out:
# __main__.Circle

# %%
s1.area()
# Out:
# 84.0

# %%
s2.area()
# Out:
# 615.7521601035994
